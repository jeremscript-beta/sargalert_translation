# %%
#===Importation des classes===
from classes_drift import Modis_Goes_Image_Processor , Modis_Goes_Translation, KeyPoints , Matching , LinearTranslation , LatLonData
# Out:
# Cannot find header.dxf (GDAL_DATA is not defined)

# %%
#création de l'objet
Translation = Modis_Goes_Translation()
Translation.number_file = 0
Translation.goes_modis_translation() #Translation test pour le premier jour
# Out:
# Loaded existing data points.
# 100%|██████████| 19/19 [00:17<00:00,  1.11it/s]
# All regions processed and new data added to the Excel file.

# %%
Translation.plot_global_map()#Affichage map global
